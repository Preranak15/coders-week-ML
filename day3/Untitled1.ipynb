# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.utils import shuffle
from sklearn.preprocessing import OneHotEncoder

# %%
dataset = pd.read_csv('http://iali.in/datasets/mushrooms.csv')
dataset.head()
# Out:
#   class cap-shape cap-surface  ... spore-print-color population habitat
# 0     p         x           s  ...                 k          s       u
# 1     e         x           s  ...                 n          n       g
# 2     e         b           s  ...                 n          n       m
# 3     p         x           y  ...                 k          s       u
# 4     e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %%
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, 4].values

# %%
names_types =('class','cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-rin','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat')
names_df = pd.DataFrame(names_types, columns=['names_Types'])

# %%
dum_df = pd.get_dummies(names_df, columns=["names_Types"], prefix=["Type_is"] )

# %%
names_df = names_df.join(dum_df)
names_df
# Out:
#                  names_Types  ...  Type_is_veil-type
# 0                      class  ...                  0
# 1                  cap-shape  ...                  0
# 2                cap-surface  ...                  0
# 3                  cap-color  ...                  0
# 4                    bruises  ...                  0
# 5                       odor  ...                  0
# 6            gill-attachment  ...                  0
# 7               gill-spacing  ...                  0
# 8                  gill-size  ...                  0
# 9                 gill-color  ...                  0
# 10               stalk-shape  ...                  0
# 11                stalk-root  ...                  0
# 12  stalk-surface-above-ring  ...                  0
# 13   stalk-surface-below-rin  ...                  0
# 14    stalk-color-above-ring  ...                  0
# 15    stalk-color-below-ring  ...                  0
# 16                 veil-type  ...                  1
# ...

# %%
import sklearn
from sklearn.tree import DecisionTreeRegressor as dt
from sklearn.model_selection import train_test_split
